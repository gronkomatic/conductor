# %%
import argparse
import numpy as np

from llama_cpp import Llama

# %%
model="C:/Users/sam/OneDrive/Documents/ai-stuff/llm-models/ggml/wizardlm-1.0-uncensored-llama2-13b.ggmlv3.q4_K_S.bin"
text="Hello world!"

# %%
llm = Llama(model_path=model, embedding=True, verbose=True)
# Out:
# AVX = 1 | AVX2 = 1 | AVX512 = 0 | AVX512_VBMI = 0 | AVX512_VNNI = 0 | FMA = 1 | NEON = 0 | ARM_FMA = 0 | F16C = 1 | FP16_VA = 0 | WASM_SIMD = 0 | BLAS = 0 | SSE3 = 1 | VSX = 0 |

# %%
embedding = llm.create_embedding(text)
print(embedding)
# Out:
# {'object': 'list', 'data': [{'object': 'embedding', 'embedding': [0.6357490420341492, -0.004267947748303413, 0.5982699394226074, 1.1798580884933472, 0.26924562454223633, 0.6364427804946899, -0.5935548543930054, -0.1851697564125061, 0.1289369761943817, 1.3635597229003906, 1.0602357387542725, 0.2319471538066864, 0.9799915552139282, 1.2573282718658447, -0.9032025337219238, -0.735978901386261, 1.0974806547164917, -0.673724353313446, -0.14869366586208344, 1.1345622539520264, -1.9698190689086914, -0.07804211974143982, 0.9256561398506165, -0.6294586658477783, -0.14927884936332703, 1.0651088953018188, 0.9896461963653564, 0.19227725267410278, -0.037088438868522644, -0.13834331929683685, -0.4596903920173645, 0.3486856520175934, -0.17103871703147888, -0.7448068261146545, -0.39259135723114014, 1.1963282823562622, -0.13077764213085175, 1.1529300212860107, 4.564657688140869, 1.008595585823059, -0.39503756165504456, 0.22403845191001892, -0.9078654050827026, 1.3877854347229004, -1.1760432720184326, 
# ...

# %%
# pretty print the embedding
len(embedding["data"][0]["embedding"])
# Out:
# 5120

# %%
# Print the size of the embedding
print(embedding.size())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 2
#       1 # Print the size of the embedding
# ----> 2 print(embedding.size())
#
# AttributeError: 'dict' object has no attribute 'size'
